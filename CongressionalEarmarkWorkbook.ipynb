# %%
# Importing necessary packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Connecting the dataset
earmarks = pd.read_csv('FY2022-Congressionally-Directed-Spending-BPC.csv')

# Quick look at the dataset
print(len(earmarks))
print(earmarks.head())
print(earmarks.info)
# Out:
# 4975
#                                             category  \
# 0  Agriculture, Rural Development, Food and Drug ...
# 1  Agriculture, Rural Development, Food and Drug ...
# 2  Agriculture, Rural Development, Food and Drug ...
# 3  Agriculture, Rural Development, Food and Drug ...
# 4  Agriculture, Rural Development, Food and Drug ...
#
#                                        agency    account  \
# 0  Animal and Plant Health Inspection Service  APHIS S&E
# 1  Animal and Plant Health Inspection Service  APHIS S&E
# 2  Animal and Plant Health Inspection Service  APHIS S&E
# 3  Animal and Plant Health Inspection Service  APHIS S&E
# 4  Animal and Plant Health Inspection Service  APHIS S&E
#
#                              project  \
# 0             Statewide Pest Surveys
# 1             Feral Swine Management
# 2      Invasive Species Surveillance
# 3          Kula Agricultural Fencing
# 4  O?Hare Federal Inspection Station
#
#                                          recipient location state  \
# 0                   Alaska Division of Agriculture      NaN    AK
# 1               Arkansas Department of Agriculture      NaN    AR
# 2  Hawaii Department of Land and Natural Resources      NaN    HI
# 3              Maui Office of Economic Development      NaN    HI
# 4                                  City of Chicago      NaN    IL
#
#    budget_request additional_amount  amount  ... requestor_seven_chamber  \
# 0             NaN               NaN  100000  ...                     NaN
# 1             NaN               NaN  650000  ...                     NaN
# 2             NaN               NaN  600000  ...                     NaN
# 3             NaN               NaN  600000  ...                     NaN
# 4             NaN               NaN  250000  ...                     NaN
#
#   requestor_seven_party requestor_eight_full_name requestor_eight_bioguide_id  \
# 0                   NaN                       NaN                         NaN
# 1                   NaN                       NaN                         NaN
# 2                   NaN                       NaN                         NaN
# 3                   NaN                       NaN                         NaN
# 4                   NaN                       NaN                         NaN
#
#   requestor_eight_chamber requestor_eight_party requestor_nine_full_name  \
# 0                     NaN                   NaN                      NaN
# 1                     NaN                   NaN                      NaN
# 2                     NaN                   NaN                      NaN
# 3                     NaN                   NaN                      NaN
# 4                     NaN                   NaN                      NaN
#
#   requestor_nine_bioguide_id requestor_nine_chamber requestor_nine_party
# 0                        NaN                    NaN                  NaN
# 1                        NaN                    NaN                  NaN
# 2                        NaN                    NaN                  NaN
# 3                        NaN                    NaN                  NaN
# 4                        NaN                    NaN                  NaN
#
# [5 rows x 47 columns]
# <bound method DataFrame.info of                                                category  \
# 0     Agriculture, Rural Development, Food and Drug ...
# 1     Agriculture, Rural Development, Food and Drug ...
# 2     Agriculture, Rural Development, Food and Drug ...
# 3     Agriculture, Rural Development, Food and Drug ...
# 4     Agriculture, Rural Development, Food and Drug ...
# ...                                                 ...
# 4970  Transportation, and Housing and Urban Developm...
# 4971  Transportation, and Housing and Urban Developm...
# 4972  Transportation, and Housing and Urban Developm...
# 4973  Transportation, and Housing and Urban Developm...
# 4974  Transportation, and Housing and Urban Developm...
#
#                                           agency  \
# 0     Animal and Plant Health Inspection Service
# 1     Animal and Plant Health Inspection Service
# 2     Animal and Plant Health Inspection Service
# 3     Animal and Plant Health Inspection Service
# 4     Animal and Plant Health Inspection Service
# ...                                          ...
# 4970                Department of Transportation
# 4971                Department of Transportation
# 4972                Department of Transportation
# 4973                Department of Transportation
# 4974                Department of Transportation
#
#                               account  \
# 0                           APHIS S&E
# 1                           APHIS S&E
# 2                           APHIS S&E
# 3                           APHIS S&E
# 4                           APHIS S&E
# ...                               ...
# 4970  Highway Infrastructure Programs
# 4971  Highway Infrastructure Programs
# 4972  Highway Infrastructure Programs
# 4973  Highway Infrastructure Programs
# 4974  Highway Infrastructure Programs
#
#                                                 project  \
# 0                                Statewide Pest Surveys
# 1                                Feral Swine Management
# 2                         Invasive Species Surveillance
# 3                             Kula Agricultural Fencing
# 4                     O?Hare Federal Inspection Station
# ...                                                 ...
# 4970  Project FIRST (Fast Tracking Improvements to R...
# 4971                       Edgewater Bridge Replacement
# 4972                         South Barker Road Corridor
# 4973  Brown County South Bridge Regional Connector P...
# 4974                              Coalfields Expressway
#
#                                             recipient location state  \
# 0                      Alaska Division of Agriculture      NaN    AK
# 1                  Arkansas Department of Agriculture      NaN    AR
# 2     Hawaii Department of Land and Natural Resources      NaN    HI
# 3                 Maui Office of Economic Development      NaN    HI
# 4                                     City of Chicago      NaN    IL
# ...                                               ...      ...   ...
# 4970                                              NaN      NaN    WA
# 4971                                              NaN      NaN    WA
# 4972                                              NaN      NaN    WA
# 4973                                              NaN      NaN    WI
# 4974                                              NaN      NaN    WV
#
#       budget_request additional_amount   amount  ... requestor_seven_chamber  \
# 0                NaN               NaN   100000  ...                     NaN
# 1                NaN               NaN   650000  ...                     NaN
# 2                NaN               NaN   600000  ...                     NaN
# 3                NaN               NaN   600000  ...                     NaN
# 4                NaN               NaN   250000  ...                     NaN
# ...              ...               ...      ...  ...                     ...
# 4970             NaN               NaN  2500000  ...                     NaN
# 4971             NaN               NaN  3000000  ...                     NaN
# 4972             NaN               NaN  3000000  ...                     NaN
# 4973             NaN               NaN  5000000  ...                     NaN
# 4974             NaN               NaN   500000  ...                     NaN
#
#      requestor_seven_party requestor_eight_full_name  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# ...                    ...                       ...
# 4970                   NaN                       NaN
# 4971                   NaN                       NaN
# 4972                   NaN                       NaN
# 4973                   NaN                       NaN
# 4974                   NaN                       NaN
#
#      requestor_eight_bioguide_id requestor_eight_chamber  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ...                          ...                     ...
# 4970                         NaN                     NaN
# 4971                         NaN                     NaN
# 4972                         NaN                     NaN
# 4973                         NaN                     NaN
# 4974                         NaN                     NaN
#
#      requestor_eight_party requestor_nine_full_name  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 4970                   NaN                      NaN
# 4971                   NaN                      NaN
# 4972                   NaN                      NaN
# 4973                   NaN                      NaN
# 4974                   NaN                      NaN
#
#      requestor_nine_bioguide_id requestor_nine_chamber requestor_nine_party
# 0                           NaN                    NaN                  NaN
# 1                           NaN                    NaN                  NaN
# 2                           NaN                    NaN                  NaN
# 3                           NaN                    NaN                  NaN
# 4                           NaN                    NaN                  NaN
# ...                         ...                    ...                  ...
# 4970                        NaN                    NaN                  NaN
# 4971                        NaN                    NaN                  NaN
# 4972                        NaN                    NaN                  NaN
# 4973                        NaN                    NaN                  NaN
# 4974                        NaN                    NaN                  NaN
#
# [4975 rows x 47 columns]>

# %%
dem_earmarks = earmarks[earmarks['requestor_one_party']=='Democrat']
print(dem_earmarks.head())
rep_earmarks = earmarks[earmarks['requestor_one_party']=='Republican']
ind_earmarks = earmarks[earmarks['requestor_one_party']=='Independent']
'''grouped = earmarks.groupby(['category']).sum()
size = 0
# Fits the size of the chart to the amount of bars there will be in the chart
for i in range(len(grouped)):
    size+=3
# Creates the plot
f,ax = plt.subplots(1, 1, figsize=(size, 10))
    
sns.barplot(x=earmarks.index, y=earmarks.amount, ax=ax)
ax.set_xticks(list(range(len(earmarks.index.unique()))))
ax.set_xticklabels(list(earmarks.index.unique()), rotation=90)
ax.set_ylabel('Amount Spent in Dollars')
ax.set_xlabel('Category')
plt.show()'''
# Out:
#                                             category  \
# 2  Agriculture, Rural Development, Food and Drug ...
# 3  Agriculture, Rural Development, Food and Drug ...
# 4  Agriculture, Rural Development, Food and Drug ...
# 5  Agriculture, Rural Development, Food and Drug ...
# 6  Agriculture, Rural Development, Food and Drug ...
#
#                                        agency    account  \
# 2  Animal and Plant Health Inspection Service  APHIS S&E
# 3  Animal and Plant Health Inspection Service  APHIS S&E
# 4  Animal and Plant Health Inspection Service  APHIS S&E
# 5  Animal and Plant Health Inspection Service  APHIS S&E
# 6  Animal and Plant Health Inspection Service  APHIS S&E
#
#                                           project  \
# 2                   Invasive Species Surveillance
# 3                       Kula Agricultural Fencing
# 4               O?Hare Federal Inspection Station
# 5                                Horse Management
# 6  New York Dairy Farms Antimicrobial Stewardship
#
#                                          recipient location state  \
# 2  Hawaii Department of Land and Natural Resources      NaN    HI
# 3              Maui Office of Economic Development      NaN    HI
# 4                                  City of Chicago      NaN    IL
# 5                 Nevada Department of Agriculture      NaN    NV
# 6                New York Farm Viability Institute      NaN    NY
#
#    budget_request additional_amount  amount  ... requestor_seven_chamber  \
# 2             NaN               NaN  600000  ...                     NaN
# 3             NaN               NaN  600000  ...                     NaN
# 4             NaN               NaN  250000  ...                     NaN
# 5             NaN               NaN  500000  ...                     NaN
# 6             NaN               NaN  180000  ...                     NaN
#
#   requestor_seven_party requestor_eight_full_name requestor_eight_bioguide_id  \
# 2                   NaN                       NaN                         NaN
# 3                   NaN                       NaN                         NaN
# 4                   NaN                       NaN                         NaN
# 5                   NaN                       NaN                         NaN
# 6                   NaN                       NaN                         NaN
#
#   requestor_eight_chamber requestor_eight_party requestor_nine_full_name  \
# 2                     NaN                   NaN                      NaN
# 3                     NaN                   NaN                      NaN
# 4                     NaN                   NaN                      NaN
# 5                     NaN                   NaN                      NaN
# 6                     NaN                   NaN                      NaN
#
#   requestor_nine_bioguide_id requestor_nine_chamber requestor_nine_party
# 2                        NaN                    NaN                  NaN
# 3                        NaN                    NaN                  NaN
# 4                        NaN                    NaN                  NaN
# 5                        NaN                    NaN                  NaN
# 6                        NaN                    NaN                  NaN
#
# [5 rows x 47 columns]
# "grouped = earmarks.groupby(['category']).sum()\nsize = 0\n# Fits the size of the chart to the amount of bars there will be in the chart\nfor i in range(len(grouped)):\n    size+=3\n# Creates the plot\nf,ax = plt.subplots(1, 1, figsize=(size, 10))\n    \nsns.barplot(x=earmarks.index, y=earmarks.amount, ax=ax)\nax.set_xticks(list(range(len(earmarks.index.unique()))))\nax.set_xticklabels(list(earmarks.index.unique()), rotation=90)\nax.set_ylabel('Amount Spent in Dollars')\nax.set_xlabel('Category')\nplt.show()"
